# %%
import pandas as pd

# %%
# uploading 311 data for all requests opened in 2016; filtered and manually downloaded to local machine from
# https://data.cityofboston.gov/City-Services/311-Service-Requests/awu8-dc52/data

data311 = pd.read_csv('311__Service_Requests.csv')

# %%
data311.head(3)
# Out:
#    CASE_ENQUIRY_ID                 OPEN_DT               TARGET_DT  \
# 0     101001892127  08/27/2016 10:21:43 AM  08/30/2016 08:30:00 AM
# 1     101001867997  07/26/2016 08:43:35 AM  07/27/2016 08:43:35 AM
# 2     101001873009  08/01/2016 04:07:00 PM                     NaN
#
#                 CLOSED_DT OnTime_Status CASE_STATUS  \
# 0  08/27/2016 03:38:38 PM        ONTIME      Closed
# 1  07/26/2016 10:58:29 AM        ONTIME      Closed
# 2                     NaN        ONTIME        Open
#
#                                       CLOSURE_REASON              CASE_TITLE  \
# 0  Case Closed. Closed date : 2016-08-27 15:38:38...           CE Collection
# 1  Case Closed. Closed date : 2016-07-26 10:58:29...     Parking Enforcement
# 2                                                NaN  Animal Generic Request
#
#                              SUBJECT                            REASON  \
# 0            Public Works Department                   Street Cleaning
# ...

# %%
num_subjects = len(data311['SUBJECT'].unique())
num_reasons = len(data311['REASON'].unique())
num_caseTitles = len(data311['CASE_TITLE'].unique())
num_requests = len(data311)

print("BOSTON'S 311 REQUESTS IN 2016")
print("Number of Subjects    :  " + str(num_subjects))
print("Number of Reasons     :  " + str(num_reasons))
print("Number of Case Titles :  " + str(num_caseTitles))
print("Number of Requests    :  " + str(num_requests))
# Out:
# BOSTON'S 311 REQUESTS IN 2016
# Number of Subjects    :  14
# Number of Reasons     :  54
# Number of Case Titles :  4238
# Number of Requests    :  219587

# %%
print (data311['SUBJECT'].unique())
# Out:
# ['Public Works Department' 'Transportation - Traffic Division'
#  'Animal Control' 'Inspectional Services' 'Property Management'
#  'Parks & Recreation Department' 'Civil Rights' "Mayor's 24 Hour Hotline"
#  'Boston Police Department' 'Boston Water & Sewer Commission'
#  'Disability Department' 'Neighborhood Services'
#  'Consumer Affairs & Licensing' 'Youthline']

# %%
# counting the complaints per subject

data2 = data311.groupby('SUBJECT')
subjects = pd.DataFrame(data2['SUBJECT'].apply(np.size))
subjects.rename(columns = {'SUBJECT':'311 Requests'}, inplace = True)
subjects.head(3)
# Out:
#                                  311 Requests
# SUBJECT
# Animal Control                           3016
# Boston Police Department                  117
# Boston Water & Sewer Commission          1236

# %%
# calculating the percentages made up by each subject

subjects['Percentage of Total'] = subjects['311 Requests'] / sum(subjects['311 Requests']) * 100
subjects.sort(columns='311 Requests', axis=0, ascending=False, inplace=True,
              kind='quicksort', na_position='last')
subjects
# Out:
# /Users/adriandahlin/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:5: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#                                    311 Requests  Percentage of Total
# SUBJECT
# Public Works Department                  114530            52.157004
# Transportation - Traffic Division         46213            21.045417
# Inspectional Services                     25473            11.600414
# Parks & Recreation Department             15476             7.047776
# Mayor's 24 Hour Hotline                    7768             3.537550
# Property Management                        3037             1.383051
# Animal Control                             3016             1.373488
# Civil Rights                               2188             0.996416
# Boston Water & Sewer Commission            1236             0.562875
# Disability Department                       499             0.227245
# ...

# %%
# public works and transportation are big categories, so trying a grouping by Reason instead

data3 = data311.groupby('REASON')
reasons = pd.DataFrame(data3['REASON'].apply(np.size))
reasons.rename(columns = {'REASON':'311 Requests'}, inplace = True)

reasons['Percentage of Total'] = reasons['311 Requests'] / sum(reasons['311 Requests']) * 100
reasons.sort(columns='311 Requests', axis=0, ascending=False, inplace=True,
              kind='quicksort', na_position='last')
reasons.head(20)
# Out:
# /Users/adriandahlin/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:9: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#                                    311 Requests  Percentage of Total
# REASON
# Enforcement & Abandoned Vehicles          29894            13.613739
# Sanitation                                28057            12.777168
# Street Cleaning                           27762            12.642825
# Highway Maintenance                       20740             9.445004
# Code Enforcement                          18583             8.462705
# Signs & Signals                           14489             6.598296
# Building                                  12566             5.722561
# Street Lights                             11031             5.023521
# Trees                                      8977             4.088129
# Housing                                    7560             3.442827
# ...
